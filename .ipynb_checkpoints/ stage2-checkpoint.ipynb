# %% [markdown]
# # stage 2
# <b style="color:Red">
# <li>Create graphs of univariate distribution of all non funding variables and share on a jupyter notebook. Just FYI - Funding FY2008, FY2009, FY2010 are the "funding variables"</li>
# <li>Calculate mutual_info_score of target variable created in stage 1 & ALL non funding variables and share on a jupyter notebook.
# </li>
# </b>

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data/ml_stem_analysis.csv')

# %%
data.head()
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
#                                 A) Brief Description  B) Year Established  \
# 0  The Division of Ocean Sciences seeks to establ...               2002.0
# 1  The BPC Program was not primarily aimed at edu...               2006.0
# 2  Through the CISE Pathways to Revitalized Under...               2007.0
# 3  The Opportunities for Enhancing Diversity in t...               2002.0
# 4  The Geoscience Education (GeoEd) program is fo...               1999.0
#
#    C1) Funding FY2008  C2) Funding FY2009  C3) Funding FY2010  \
# 0                5.24                7.19                5.70
# 1               14.00               14.00               14.00
# 2                5.00                5.00                4.37
# 3                4.57               11.79                4.18
# 4                1.63                2.74                2.02
#
#   D) Mission-specific or General STEM?  ...    \
# 0                         General STEM  ...
# 1                         General STEM  ...
# 2                         General STEM  ...
# 3                         General STEM  ...
# 4                         General STEM  ...
#
#   Y3) Process or Implementation Evaluation Type  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                   INDEPENDENT
# 4                                           NaN
#
#   Y3) Process or Implementation Evaluation Type 1  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Y3) Process or Implementation Evaluation Type 2  \
# 0                                              NO
# 1                                              NO
# 2                                              NO
# 3                                             NaN
# 4                                              NO
#
#   Y4) Portfolio Evaluation/Review Type Y4) Portfolio Evaluation/Review Type 1  \
# 0                          INDEPENDENT                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                          INDEPENDENT                                    NaN
# 4                                  NaN                                    NaN
#
#   Y4) Portfolio Evaluation/Review Type 2 Y5) Expert Review Type  \
# 0                                    NaN            INDEPENDENT
# 1                                     NO                    NaN
# 2                                     NO                    NaN
# 3                                    NaN            INDEPENDENT
# 4                                     NO                    NaN
#
#   Y5) Expert Review Type 1      Growth target
# 0                      NaN   37.213740      1
# 1                      NaN    0.000000      1
# 2                      NaN    0.000000      1
# 3                      NaN  157.986871      1
# 4                      NaN   68.098160      1
#
# [5 rows x 258 columns]

# %%
# last row is having almost NAN values hence dropped 
data.drop(252,inplace=True)

# %%
data.describe()
# Out:
#        B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# count           241.000000          252.000000          252.000000
# mean           1998.464730           11.098554           13.311074
# std              11.653317           28.597586           35.676249
# min            1914.000000            0.000000            0.000000
# 25%            1993.000000            0.474025            0.712500
# 50%            2002.000000            1.650000            1.994500
# 75%            2007.000000            6.764750            7.995000
# max            2010.000000          259.076349          341.000000
#
#        C3) Funding FY2010  P) External Funding Allocation  \
# count          252.000000                             0.0
# mean            13.592407                             NaN
# std             35.751874                             NaN
# min              0.000000                             NaN
# 25%              0.852750                             NaN
# 50%              2.455000                             NaN
# 75%              9.276750                             NaN
# max            379.776000                             NaN
#
#        R1) Joint Funding of Investment (with Agencies)  \
# count                                              0.0
# mean                                               NaN
# std                                                NaN
# min                                                NaN
# 25%                                                NaN
# 50%                                                NaN
# 75%                                                NaN
# max                                                NaN
#
#        R1) Joint Funding of Investment (with Agencies) 2  \
# count                                          12.000000
# mean                                            1.650048
# std                                             1.910847
# min                                             0.050000
# 25%                                             0.198375
# 50%                                             0.737625
# 75%                                             3.250457
# max                                             5.000000
#
#        R1) Joint Funding of Investment (with Agencies) 5  \
# count                                           4.000000
# mean                                            1.048625
# std                                             1.392363
# min                                             0.044500
# 25%                                             0.048625
# 50%                                             0.575000
# 75%                                             1.575000
# max                                             3.000000
#
#        R1) Joint Funding of Investment (with Agencies) 8  \
# count                                             1.0000
# mean                                              0.0445
# std                                                  NaN
# min                                               0.0445
# 25%                                               0.0445
# 50%                                               0.0445
# 75%                                               0.0445
# max                                               0.0445
#
#        R1) Joint Funding of Investment (with Agencies) 11  \
# count                                              1.000
# mean                                               0.089
# std                                                  NaN
# min                                                0.089
# 25%                                                0.089
# 50%                                                0.089
# 75%                                                0.089
# max                                                0.089
#
#        R2) Joint Funding of Investment (with Other) 4  \
# count                                        2.000000
# mean                                         0.887000
# std                                          1.112986
# min                                          0.100000
# 25%                                          0.493500
# 50%                                          0.887000
# 75%                                          1.280500
# max                                          1.674000
#
#        R2) Joint Funding of Investment (with Other) 7  \
# count                                            1.00
# mean                                             1.82
# std                                               NaN
# min                                              1.82
# 25%                                              1.82
# 50%                                              1.82
# 75%                                              1.82
# max                                              1.82
#
#        R2) Joint Funding of Investment (with Other) 10       Growth  \
# count                                            1.000   252.000000
# mean                                             2.204    35.189945
# std                                                NaN   110.418532
# min                                              2.204  -100.000000
# 25%                                              2.204     0.000000
# 50%                                              2.204     4.966815
# 75%                                              2.204    42.147393
# max                                              2.204  1400.000000
#
#            target
# count  252.000000
# mean     0.793651
# std      0.405489
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# # Removing  attribute

# %%
#contain only NaN
data = data.drop(['P) External Funding Allocation','R1) Joint Funding of Investment (with Agencies)'],axis=1)

# %%
data.describe()
# Out:
#        B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# count           241.000000          252.000000          252.000000
# mean           1998.464730           11.098554           13.311074
# std              11.653317           28.597586           35.676249
# min            1914.000000            0.000000            0.000000
# 25%            1993.000000            0.474025            0.712500
# 50%            2002.000000            1.650000            1.994500
# 75%            2007.000000            6.764750            7.995000
# max            2010.000000          259.076349          341.000000
#
#        C3) Funding FY2010  R1) Joint Funding of Investment (with Agencies) 2  \
# count          252.000000                                          12.000000
# mean            13.592407                                           1.650048
# std             35.751874                                           1.910847
# min              0.000000                                           0.050000
# 25%              0.852750                                           0.198375
# 50%              2.455000                                           0.737625
# 75%              9.276750                                           3.250457
# max            379.776000                                           5.000000
#
#        R1) Joint Funding of Investment (with Agencies) 5  \
# count                                           4.000000
# mean                                            1.048625
# std                                             1.392363
# min                                             0.044500
# 25%                                             0.048625
# 50%                                             0.575000
# 75%                                             1.575000
# max                                             3.000000
#
#        R1) Joint Funding of Investment (with Agencies) 8  \
# count                                             1.0000
# mean                                              0.0445
# std                                                  NaN
# min                                               0.0445
# 25%                                               0.0445
# 50%                                               0.0445
# 75%                                               0.0445
# max                                               0.0445
#
#        R1) Joint Funding of Investment (with Agencies) 11  \
# count                                              1.000
# mean                                               0.089
# std                                                  NaN
# min                                                0.089
# 25%                                                0.089
# 50%                                                0.089
# 75%                                                0.089
# max                                                0.089
#
#        R2) Joint Funding of Investment (with Other) 4  \
# count                                        2.000000
# mean                                         0.887000
# std                                          1.112986
# min                                          0.100000
# 25%                                          0.493500
# 50%                                          0.887000
# 75%                                          1.280500
# max                                          1.674000
#
#        R2) Joint Funding of Investment (with Other) 7  \
# count                                            1.00
# mean                                             1.82
# std                                               NaN
# min                                              1.82
# 25%                                              1.82
# 50%                                              1.82
# 75%                                              1.82
# max                                              1.82
#
#        R2) Joint Funding of Investment (with Other) 10       Growth  \
# count                                            1.000   252.000000
# mean                                             2.204    35.189945
# std                                                NaN   110.418532
# min                                              2.204  -100.000000
# 25%                                              2.204     0.000000
# 50%                                              2.204     4.966815
# 75%                                              2.204    42.147393
# max                                              2.204  1400.000000
#
#            target
# count  252.000000
# mean     0.793651
# std      0.405489
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
# removing attribute which contain values only in few rows
col=['R1) Joint Funding of Investment (with Agencies) 2','R1) Joint Funding of Investment (with Agencies) 5',
     'R1) Joint Funding of Investment (with Agencies) 8','R1) Joint Funding of Investment (with Agencies) 11',
     'R2) Joint Funding of Investment (with Other) 4','R2) Joint Funding of Investment (with Other) 7',
     'R2) Joint Funding of Investment (with Other) 10'
    ]
data=data.drop(col,axis=1)

# %%
data.describe()
# Out:
#        B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# count           241.000000          252.000000          252.000000
# mean           1998.464730           11.098554           13.311074
# std              11.653317           28.597586           35.676249
# min            1914.000000            0.000000            0.000000
# 25%            1993.000000            0.474025            0.712500
# 50%            2002.000000            1.650000            1.994500
# 75%            2007.000000            6.764750            7.995000
# max            2010.000000          259.076349          341.000000
#
#        C3) Funding FY2010       Growth      target
# count          252.000000   252.000000  252.000000
# mean            13.592407    35.189945    0.793651
# std             35.751874   110.418532    0.405489
# min              0.000000  -100.000000    0.000000
# 25%              0.852750     0.000000    1.000000
# 50%              2.455000     4.966815    1.000000
# 75%              9.276750    42.147393    1.000000
# max            379.776000  1400.000000    1.000000

# %%
# removing attribute that contain different values in all rows or same value in all rows
for each in data.columns:
    if(len(list(data[each].value_counts())) ==252) or (len(list(data[each].value_counts())) ==251) or (len(list(data[each].value_counts())) ==1):
        data = data.drop(each,axis=1)

# %%
# removing the value that have most value NaN
for each in data.columns:
    if ( data[each].isnull().sum() > int(252*.6)):
        data = data.drop(each,axis=1)

# %%
data.head()
# Out:
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  B) Year Established  \
# 0                  Directorate for Geosciences (GEO)               2002.0
# 1  Directorate for Computer & Information Science...               2006.0
# 2  Directorate for Computer & Information Science...               2007.0
# 3                  Directorate for Geosciences (GEO)               2002.0
# 4                  Directorate for Geosciences (GEO)               1999.0
#
#    C1) Funding FY2008  C2) Funding FY2009  C3) Funding FY2010  \
# 0                5.24                7.19                5.70
# 1               14.00               14.00               14.00
# 2                5.00                5.00                4.37
# 3                4.57               11.79                4.18
# 4                1.63                2.74                2.02
#
#   D) Mission-specific or General STEM?  \
# 0                         General STEM
# 1                         General STEM
# 2                         General STEM
# 3                         General STEM
# 4                         General STEM
#
#   E) Agency or Mission-Related Workforce Needs?  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                     F1) Primary Investment Objective  \
# 0  Institutional Capacity: Support advancement an...
# 1  Engagement: Increase learners’ engagement, int...
# 2  Institutional Capacity: Support advancement an...
# 3  Engagement: Increase learners’ engagement, int...
# 4  Learning: Develop STEM skills, practices, or k...
#
#   I1) STEM Learners Targeted? Specify.  ...    \
# 0                                  NaN  ...
# 1                    Pre-K-20 learners  ...
# 2                                  NaN  ...
# 3                    Pre-K-20 learners  ...
# 4                    Pre-K-20 learners  ...
#
#                                 M) Geographic Region M) Geographic Region 1  \
# 0  National scope or not targeted to a geographic...                      x
# 1  National scope or not targeted to a geographic...                      x
# 2  National scope or not targeted to a geographic...                      x
# 3  National scope or not targeted to a geographic...                      x
# 4  National scope or not targeted to a geographic...                      x
#
#   N) STEM Discipline Focus 12 Q) Legislation Required to Shift Focus?  \
# 0                         NaN                              Don't know
# 1                         NaN                              Don't know
# 2                         NaN                              Don't know
# 3                         NaN                              Don't know
# 4                         NaN                              Don't know
#
#   S) Investment Partnerships                  U) Measured Outputs  \
# 0                   Required                                  NaN
# 1                 Encouraged                                  NaN
# 2                 Encouraged                                  NaN
# 3                 Encouraged  Number of learners (any age) served
# 4                 Encouraged                                  NaN
#
#   V) Outcomes Measured X) Evaluated Since 2005?      Growth target
# 0                  NaN                      YES   37.213740      1
# 1                  NaN                      YES    0.000000      1
# 2                 NONE                      YES    0.000000      1
# 3                  NaN                      YES  157.986871      1
# 4                 NONE                      YES   68.098160      1
#
# [5 rows x 25 columns]

# %%
data.to_csv("stem_useful_feature.csv",index=False)

# %%
data2=data

# %% [markdown]
# # Univariate graph

# %%
#removing the column of all funding variable and Growth
col=['C1) Funding FY2008','C2) Funding FY2009','C3) Funding FY2010','Growth']
data2= data2.drop(col,axis=1)
data2=data2.drop('target',axis=1)

# %%
columns=data2.columns

# %%
columns
# Out:
# Index(['Agency', 'Subagency', 'B) Year Established',
#        'D) Mission-specific or General STEM?',
#        'E) Agency or Mission-Related Workforce Needs?',
#        'F1) Primary Investment Objective',
#        'I1) STEM Learners Targeted? Specify.',
#        'I1) STEM Learners Targeted? Specify. 5',
#        'I1) STEM Learners Targeted? Specify. 6',
#        'J) Focus on Underrepresented Groups in STEM',
#        'K) Eligibility Restrictions', 'L) Minority Serving Institutions',
#        'M) Geographic Region', 'M) Geographic Region 1',
#        'N) STEM Discipline Focus 12',
#        'Q) Legislation Required to Shift Focus?', 'S) Investment Partnerships',
#        'U) Measured Outputs', 'V) Outcomes Measured',
#        'X) Evaluated Since 2005?'],
#       dtype='object')

# %% [markdown]
# # Analysis of 20 non funding variable

# %%
plt.style.available
# Out:
# ['seaborn-darkgrid',
#  'classic',
#  'seaborn-colorblind',
#  'seaborn-paper',
#  'seaborn-notebook',
#  'seaborn-deep',
#  'seaborn-pastel',
#  'seaborn-muted',
#  'seaborn',
#  'seaborn-whitegrid',
#  'seaborn-talk',
#  'seaborn-bright',
#  'seaborn-dark-palette',
#  'fivethirtyeight',
#  'dark_background',
#  'seaborn-dark',
#  'ggplot',
#  'seaborn-white',
#  '_classic_test',
#  'seaborn-ticks',
#  'grayscale',
#  'seaborn-poster',
#  'bmh']

# %%
plt.style.use('ggplot')

# %%
ax = data2['Agency'].value_counts().plot(kind='barh', figsize=(10,7),
                                        color="Blue", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("Agency", fontsize=18)
ax.set_xlabel( "Counts", fontsize=18);
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_width())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.3, i.get_y()+.38, \
            str(round((i.get_width()/total)*100, 2))+'%', fontsize=15,
color='dimgrey')

# invert for largest on top 
ax.invert_yaxis()

# %%
 ax = data2['Subagency'].value_counts().plot(kind='barh', figsize=(10,50),
                                        color="Blue", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("Subagency", fontsize=18)
ax.set_xlabel( "Counts", fontsize=18);
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_width())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.3, i.get_y()+.38, \
            str(i.get_width()), fontsize=15,
color='dimgrey')

# invert for largest on top 
ax.invert_yaxis()

# %% [markdown]
# # histogram

# %%
custom_bucket_array = np.linspace(1910,2010,11)
ax=pd.cut(data['B) Year Established'], custom_bucket_array).value_counts().plot(kind='barh')
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_width())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.3, i.get_y()+.38, \
            str(i.get_width()), fontsize=15,
color='dimgrey')
ax.set_title("'B) Year Established'")
 
# invert for largest on top 
ax.invert_yaxis()

# %% [markdown]
# # Pie charts

# %%
# Pie chart
col = data['D) Mission-specific or General STEM?'].value_counts()
labels = col.index
sizes = col.values 
 
#colors
colors = ['#ff9999','#66b3ff' ]
 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
fig.set_size_inches(4,4)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal') 
ax1.set_title("D) Mission-specific or General STEM?")
plt.tight_layout()
plt.show()

# %%
# Pie chart
col = data2['E) Agency or Mission-Related Workforce Needs?'].value_counts()
labels = col.index
sizes = col.values 
 
#colors
colors = ['#ff9999','#66b3ff' ]
 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90 )#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
fig.set_size_inches(4,4)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal') 
ax1.set_title('E) Agency or Mission-Related Workforce Needs?')
plt.tight_layout()
plt.show()

# %%
ax=data2['N) STEM Discipline Focus 12'].value_counts().plot(kind='barh',figsize=(10,500),
                                        color="Yellow", fontsize=13)
plt.title("'N) STEM Discipline Focus 12'")
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_width())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()-.3, i.get_y()+.38, \
            str(i.get_width()), fontsize=15,
color='dimgrey')

# %% [markdown]
# # plotting all graphs together

# %%
non_fy_var=list(data2.columns)
non_fy_var.remove("N) STEM Discipline Focus 12")

# %% [markdown]
# non_fy_var.remove("C1) Funding FY2008")
# non_fy_var.remove('C2) Funding FY2009')
# non_fy_var.remove( 'C3) Funding FY2010')

# %%
non_fy_var
# Out:
# ['Agency',
#  'Subagency',
#  'B) Year Established',
#  'D) Mission-specific or General STEM?',
#  'E) Agency or Mission-Related Workforce Needs?',
#  'F1) Primary Investment Objective',
#  'I1) STEM Learners Targeted? Specify.',
#  'I1) STEM Learners Targeted? Specify. 5',
#  'I1) STEM Learners Targeted? Specify. 6',
#  'J) Focus on Underrepresented Groups in STEM',
#  'K) Eligibility Restrictions',
#  'L) Minority Serving Institutions',
#  'M) Geographic Region',
#  'M) Geographic Region 1',
#  'Q) Legislation Required to Shift Focus?',
#  'S) Investment Partnerships',
#  'U) Measured Outputs',
#  'V) Outcomes Measured',
#  'X) Evaluated Since 2005?']

# %%
for each in non_fy_var[5:]:
    plt.figure()
    plt.title(each,fontsize=20)
    data2[each].value_counts().plot(kind='barh',figsize=(5,5),
                                        color="Blue", fontsize=13)
    plt.show()
    print('\n\n')

# %% [markdown]
# ### Mutual info score

# %%
 
from sklearn.metrics import mutual_info_score
 
def MI(df,y):
    lt=[]
    for i in df.columns:
        j=df[i]
        lt.append(mutual_info_score(j.values,y))
    mi_score=pd.DataFrame(lt,columns=["mutual info score"])
    mi_score["column name"]=df.columns
    mi_score.set_index("column name",inplace=True)
    return mi_score
data=pd.read_csv('ml_stem_analysis.csv')
df1 = data
#print(df1.columns)
y1 = df1['target']
df1 = df1.drop('target',axis=1)

df1.fillna(0,inplace=True)
#6 and 9 for non- funding variables
for i in df1.columns[:6]:
    j=df1[i]
    j.replace(df1[df1[i]!=0][i].unique(),range(1,len(df1[df1[i]!=0][i].unique())+1),inplace=True)
for i in df1.columns[9:]:
    j=df1[i]
    j.replace(df1[df1[i]!=0][i].unique(),range(1,len(df1[df1[i]!=0][i].unique())+1),inplace=True)    
mutual_info_score = pd.concat([MI(df1.iloc[:,0:6],y1),MI(df1.iloc[:,9:],y1)])

# %%
mutual_info_score.to_csv("data/MI.csv",index=True)

# %%
MI_data=pd.read_csv("data/MI.csv")

# %%
MI_data
# Out:
#                                          column name  mutual info score
# 0                                       Index Number           0.507979
# 1                                    Investment Name           0.507979
# 2                                             Agency           0.029627
# 3                                          Subagency           0.158575
# 4                               A) Brief Description           0.507979
# 5                                B) Year Established           0.105631
# 6               D) Mission-specific or General STEM?           0.003061
# 7      E) Agency or Mission-Related Workforce Needs?           0.002996
# 8                   F1) Primary Investment Objective           0.011582
# 9                F2) Secondary Investment Objectives           0.001916
# 10             F2) Secondary Investment Objectives 1           0.000314
# 11             F2) Secondary Investment Objectives 2           0.004046
# 12             F2) Secondary Investment Objectives 3           0.000003
# 13             F2) Secondary Investment Objectives 4           0.001538
# 14             F2) Secondary Investment Objectives 5           0.002056
# 15             F2) Secondary Investment Objectives 6           0.009801
# 16             F2) Secondary Investment Objectives 7           0.000214
# 17             F2) Secondary Investment Objectives 8           0.002441
# 18             F2) Secondary Investment Objectives 9           0.059777
# 19                   G1) Primary Research Approaches           0.001067
# 20                 G1) Primary Research Approaches 1           0.000064
# 21                 G1) Primary Research Approaches 2           0.000237
# 22                 G1) Primary Research Approaches 3           0.000243
# 23                 G1) Primary Research Approaches 4           0.007586
# 24                 G2) Secondary Research Approaches           0.005508
# 25               G2) Secondary Research Approaches 1           0.009105
# 26               G2) Secondary Research Approaches 2           0.000020
# 27               G2) Secondary Research Approaches 3           0.001227
# 28               G2) Secondary Research Approaches 4           0.000265
# 29                  G3) Research Approaches Not Used           0.000052
# ..                                               ...                ...
# 224                           V) Outcomes Measured 2           0.000607
# 225                           V) Outcomes Measured 3           0.000155
# 226                           V) Outcomes Measured 4           0.000722
# 227                           V) Outcomes Measured 5           0.002034
# 228                           V) Outcomes Measured 6           0.001969
# 229                           V) Outcomes Measured 7           0.009303
# 230                           V) Outcomes Measured 8           0.000765
# 231                           V) Outcomes Measured 9           0.000008
# 232                          V) Outcomes Measured 10           0.003670
# 233                          V) Outcomes Measured 11           0.007035
# 234                          V) Outcomes Measured 12           0.135336
# 235                  W) Measurement Instruments Used           0.172105
# 236                W) Measurement Instruments Used 1           0.100602
# 237                W) Measurement Instruments Used 2           0.046058
# 238                         X) Evaluated Since 2005?           0.007445
# 239                    Y1) Formative Evaluation Type           0.001199
# 240                  Y1) Formative Evaluation Type 1           0.003193
# 241                  Y1) Formative Evaluation Type 2           0.004048
# 242                    Y2) Summative Evaluation Type           0.000842
# 243                  Y2) Summative Evaluation Type 1           0.000722
# 244                  Y2) Summative Evaluation Type 2           0.000068
# 245    Y3) Process or Implementation Evaluation Type           0.004757
# 246  Y3) Process or Implementation Evaluation Type 1           0.000013
# 247  Y3) Process or Implementation Evaluation Type 2           0.000308
# 248             Y4) Portfolio Evaluation/Review Type           0.001140
# 249           Y4) Portfolio Evaluation/Review Type 1           0.006775
# 250           Y4) Portfolio Evaluation/Review Type 2           0.000022
# 251                           Y5) Expert Review Type           0.008302
# 252                         Y5) Expert Review Type 1           0.002480
# 253                                           Growth           0.507979
#
# [254 rows x 2 columns]

# %%
len(df1.columns)
# Out:
# 257
